# %%
from utils.inference import generate_text

MODEL = "gpt-4o-mini"

text = await generate_text(MODEL, "Hello, how are you?")
text
# Out:
# "Hello! I'm just a program, so I don't have feelings, but I'm here and ready to help you. How can I assist you today?"

# %%
# !pip install sympy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sympy
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 13.3 MB/s eta 0:00:00a 0:00:01
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy
# Successfully installed mpmath-1.3.0 sympy-1.13.3
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
from sympy import symbols, integrate, sqrt, log, atan

# Define variable
x = symbols('x')

# Define the integrand
integrand = 1/(x**2 - x + 1)

# Perform indefinite integration
result = integrate(integrand, x)
print(f"Antiderivative: {result}")
# Out:
# Antiderivative: 2*sqrt(3)*atan(2*sqrt(3)*x/3 - sqrt(3)/3)/3

# %%
result.subs(x, 2).evalf()
# Out:
# 1.20919957615615

# %%
from generate_variants import process_integral

text = "integrate(1/(x**2 - x + 1), x)"
# text = variants[0]["variant"]
difficulties = ["easier"]
variants = await process_integral(text, difficulties, num_variants=50)
# Out:
# Error computing solution/evaluations: cannot determine truth value of Relational
# Error verifying integral: Sympify of expression 'could not parse '1/((2x - 1)^2 + 3/4)'' failed, because of exception being raised:
# SyntaxError: invalid syntax (<string>, line 1)
# Error verifying integral: Sympify of expression 'could not parse '1/(x**2 - 0.5x + 0.5)'' failed, because of exception being raised:
# SyntaxError: invalid syntax (<string>, line 1)
# Error computing solution/evaluations: cannot determine truth value of Relational
# Error computing solution/evaluations: cannot determine truth value of Relational
# Error computing solution/evaluations: cannot determine truth value of Relational

# %%
variants
# Out:
# [{'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x**2 + 1), x)',
#   'reasoning': 'As a calculus professor, I appreciate integrals that can be tackled with straightforward techniques. By simplifying the denominator, I can rewrite the integrand as a rational function that is easier to integrate.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['change a function to an easier one',
#    'reduce the number of terms in the expression',
#    'simplify a trigonometric component',
#    'remove logarithmic terms',
#    'remove a factor'],
#   'solution': 'atan(x)',
#   'evaluations': {4.672: 1.3599309954497159,
#    -5.488: -1.3905563384072228,
#    -3.398: -1.2846065732481333},
#   'timestamp': '2025-02-02T23:02:51.848955Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(tan(x)**2 + 1), x)',
#   'reasoning': 'As a creative mathematician, I love transforming difficult integrals into simpler forms. By substituting \\(x = tan(theta)\\), I can convert the integral into one involving trigonometric functions, which are often easier to handle.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['change a function to an easier one',
#    'reduce the number of terms in the expression',
#    'simplify a trigonometric component',
#    'remove logarithmic terms',
#    'remove a factor'],
#   'solution': 'x*tan(x)**2/(2*tan(x)**2 + 2) + x/(2*tan(x)**2 + 2) + tan(x)/(2*tan(x)**2 + 2)',
#   'evaluations': {8.472: 3.9998186269151543,
#    -3.677: -2.057864634933132,
#    2.061: 0.8227811548577895},
#   'timestamp': '2025-02-02T23:02:52.104948Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/((x - 1/2)**2 + 3/4), x)',
#   'reasoning': 'As a student who prefers working with polynomials, I want to express the denominator as a product of simpler factors. I recognize that \\(x^2 - x + 1\\) can be approached by completing the square.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['change a function to an easier one',
#    'reduce the number of terms in the expression',
#    'simplify a trigonometric component',
#    'remove logarithmic terms',
#    'remove a factor'],
#   'solution': '2*sqrt(3)*atan(2*sqrt(3)*x/3 - sqrt(3)/3)/3',
#   'evaluations': {-6.717: -1.6759001953905208,
#    -5.759: -1.6550379510031412,
#    6.06: 1.635382650512877},
#   'timestamp': '2025-02-02T23:02:51.868082Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x + 1), x)',
#   'reasoning': 'As an engineer who favors computational approaches, I look for integrals with numerical solutions. By changing the function to a simpler rational function, I can easily compute the integral.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['change a function to an easier one',
#    'reduce the number of terms in the expression',
#    'simplify a trigonometric component',
#    'remove logarithmic terms',
#    'remove a factor'],
#   'solution': 'log(x + 1)',
#   'evaluations': {2.72: 1.3136641849515713,
#    2.287: 1.1899445628826362,
#    2.808: 1.3370065991559767},
#   'timestamp': '2025-02-02T23:02:51.713644Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x**2 + 2), x)',
#   'reasoning': 'As a number theorist fascinated by prime numbers, I might explore the roots of the polynomial and relate it to simpler rational functions. By using a prime number as a constant, I can create an easier integral.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['change a function to an easier one',
#    'reduce the number of terms in the expression',
#    'simplify a trigonometric component',
#    'remove logarithmic terms',
#    'remove a factor'],
#   'solution': 'sqrt(2)*atan(sqrt(2)*x/2)/2',
#   'evaluations': {-7.675: -0.981877971682002,
#    -4.353: -0.8886051868837137,
#    2.497: 0.7463728547431305},
#   'timestamp': '2025-02-02T23:02:51.752928Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x - 1), x)',
#   'reasoning': 'As a geometry enthusiast, I like viewing integrals in terms of area under curves. A simple rational function related to a basic geometrical shape could represent an easier version of this integral.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['change a function to an easier one',
#    'reduce the number of terms in the expression',
#    'simplify a trigonometric component',
#    'remove logarithmic terms',
#    'remove a factor'],
#   'solution': 'log(x - 1)',
#   'evaluations': {6.78: 1.7544376835042095,
#    9.385: 2.1264079998805134,
#    7.975: 1.9423446251945529},
#   'timestamp': '2025-02-02T23:02:51.768899Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(2/(x**2 - x + 1), x)',
#   'reasoning': 'As an engineer, I often work with integrals that arise in linear systems. By introducing a constant to scale the denominator, I can facilitate easier integration and produce an approachable result.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['change a function to an easier one',
#    'reduce the number of terms in the expression',
#    'simplify a trigonometric component',
#    'remove logarithmic terms',
#    'remove a factor'],
#   'solution': '4*sqrt(3)*atan(2*sqrt(3)*x/3 - sqrt(3)/3)/3',
#   'evaluations': {-3.055: -3.0757201996430266,
#    -7.598: -3.381572047068686,
#    -3.718: -3.1599845053313302},
#   'timestamp': '2025-02-02T23:02:52.757694Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(1 + x**2), x)',
#   'reasoning': 'From the perspective of a theoretical physicist, transforming the integrand into a form involving trigonometric representations can facilitate easier integration. I substitute \\( u = \\tan^{-1}(x) \\), leading to simpler expressions.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['remove nested functions',
#    'simplify composite trigonometric functions',
#    'remove logarithmic terms',
#    'reduce the degree of a polynomial',
#    'replace a complex fraction with a simpler one'],
#   'solution': 'atan(x)',
#   'evaluations': {-2.831: -1.2312001452902193,
#    0.115: 0.11483882929293002,
#    6.263: 1.4124568784894418},
#   'timestamp': '2025-02-02T23:02:51.923643Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/x**2, x)',
#   'reasoning': 'Viewing the integral from an engineering point of view, I see that integrating simple fractions can often boil down to basic algebra. By breaking down the original fraction into simpler parts, I can reduce complexity.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['remove nested functions',
#    'simplify composite trigonometric functions',
#    'remove logarithmic terms',
#    'reduce the degree of a polynomial',
#    'replace a complex fraction with a simpler one'],
#   'solution': '-1/x',
#   'evaluations': {9.25: -0.10810644727784831,
#    -9.847: 0.1015574067339221,
#    -9.619: 0.10395567931125857},
#   'timestamp': '2025-02-02T23:02:51.819537Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/x, x)',
#   'reasoning': 'From the standpoint of a calculus professor, I like integrals that involve basic reciprocal functions. The function \\( \\frac{1}{x} \\) is a classic and provides a lot of practice with integration techniques.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['remove nested functions',
#    'simplify composite trigonometric functions',
#    'remove logarithmic terms',
#    'reduce the degree of a polynomial',
#    'replace a complex fraction with a simpler one'],
#   'solution': 'log(x)',
#   'evaluations': {5.789: 1.7558903704871547,
#    2.675: 0.9838246502163094,
#    5.796: 1.7572243033497914},
#   'timestamp': '2025-02-02T23:02:51.805410Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(e**(log(x^2 - x + 1))), x)',
#   'reasoning': "From a theoretical physicist's standpoint, I'd prefer to express the integral in terms of exponential functions if possible. I'll use Euler's formula to represent the denominator in a more manageable form.",
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['remove nested functions',
#    'replace a complex fraction with a simpler one',
#    'reduce the degree of a polynomial',
#    'simplify the denominator',
#    'drop a subexpression'],
#   'solution': None,
#   'evaluations': {},
#   'timestamp': '2025-02-02T23:02:51.853986Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1, x)',
#   'reasoning': "As an engineer focused on practical approaches, I like approximations. I'll approximate the quadratic in the denominator by its linear term for small \\( x \\): \\( x^2 - x + 1 \\approx 1 \\).",
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['remove nested functions',
#    'replace a complex fraction with a simpler one',
#    'reduce the degree of a polynomial',
#    'simplify the denominator',
#    'drop a subexpression'],
#   'solution': 'x',
#   'evaluations': {8.643: 8.643143318158476,
#    5.734: 5.7341350884057345,
#    -0.739: -0.7393432632482799},
#   'timestamp': '2025-02-02T23:02:51.743436Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x + 1/2), x)',
#   'reasoning': "As a calculus professor again, I can further simplify by considering the polynomial's behavior at boundaries. Focusing only on a small domain can make calculations easier.",
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['remove nested functions',
#    'replace a complex fraction with a simpler one',
#    'reduce the degree of a polynomial',
#    'simplify the denominator',
#    'drop a subexpression'],
#   'solution': 'log(2*x + 1)',
#   'evaluations': {0.646: 0.8291204330041267,
#    6.083: 2.5776764052427628,
#    2.752: 1.8725533688710434},
#   'timestamp': '2025-02-02T23:02:51.731209Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x**2 - x + 1), x)',
#   'reasoning': 'As an engineer, I want quick results. A numerical method can bypass complicated integrals entirely.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['remove nested functions',
#    'replace a complex fraction with a simpler one',
#    'reduce the degree of a polynomial',
#    'simplify the denominator',
#    'drop a subexpression'],
#   'solution': '2*sqrt(3)*atan(2*sqrt(3)*x/3 - sqrt(3)/3)/3',
#   'evaluations': {5.914: 1.6306425035921013,
#    -7.256: -1.6854069866317527,
#    2.897: 1.4135246722560249},
#   'timestamp': '2025-02-02T23:02:51.897603Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(4/(4*x**2 - 4*x + 4), x)',
#   'reasoning': 'As a number theorist, I might make the integral easier by examining an equivalent form using rational coefficients, focusing on symmetry for straightforward calculations.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['replace a complex fraction with a simpler one',
#    'simplify a trigonometric component',
#    'reduce the degree of a polynomial',
#    'convert a product to a simpler sum',
#    'eliminate absolute value terms'],
#   'solution': '2*sqrt(3)*atan(2*sqrt(3)*x/3 - sqrt(3)/3)/3',
#   'evaluations': {3.034: 1.4334719742632822,
#    -0.767: -1.1212882214010924,
#    -2.466: -1.4858107158748224},
#   'timestamp': '2025-02-02T23:02:47.560017Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(1 - (x - 1/2)**2), x)',
#   'reasoning': 'The geometry enthusiast suggests considering geometric transformations. Here, rewriting the expression can relate to the unit circle, making the integration visually intuitive.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['replace a complex fraction with a simpler one',
#    'simplify a trigonometric component',
#    'reduce the degree of a polynomial',
#    'convert a product to a simpler sum',
#    'eliminate absolute value terms'],
#   'solution': '-log(x - 3/2)/2 + log(x + 1/2)/2',
#   'evaluations': {-8.104: -0.11675262500797863,
#    3.378: 0.36257701469540754,
#    -4.015: -0.22519864265701442},
#   'timestamp': '2025-02-02T23:02:47.559675Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x - (1/2) + (3/4)**(1/2)), x)',
#   'reasoning': 'Thinking like an engineer, I’ll break down the integral into partial fractions. This yields simpler components that are easier to integrate.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['replace a complex fraction with a simpler one',
#    'simplify a trigonometric component',
#    'reduce the degree of a polynomial',
#    'convert a product to a simpler sum',
#    'eliminate absolute value terms'],
#   'solution': 'log(2*x - 1 + sqrt(3))',
#   'evaluations': {4.915: 2.3572132427670613,
#    2.72: 1.8201610175997278,
#    8.777: 2.90613960817005},
#   'timestamp': '2025-02-02T23:02:47.558075Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x^2 - x + 1), x)',
#   'reasoning': 'Seeing this from the perspective of a student who prefers working with polynomials, I might express the denominator in a more manageable polynomial form and then integrate using long division or polynomial methods.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['simplify composite trigonometric functions',
#    'lower a coefficient',
#    'remove a factor'],
#   'solution': '2*sqrt(3)*atan(2*sqrt(3)*x/3 - sqrt(3)/3)/3',
#   'evaluations': {3.927: 1.527965208805037,
#    5.098: 1.5988107204637267,
#    -7.414: -1.687939468935772},
#   'timestamp': '2025-02-02T23:02:51.679672Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(sqrt(3)/2**2 + (x - 1/2)**2), x)',
#   'reasoning': 'As a theoretical physicist, I recognize the utility of converting the integrand into its exponential form for easier integration, especially recognizing the periodic nature of \\(cos\\) and \\(sin\\).',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['simplify composite trigonometric functions',
#    'lower a coefficient',
#    'remove a factor'],
#   'solution': '2*3**(3/4)*atan(2*3**(3/4)*x/3 - 3**(3/4)/3)/3',
#   'evaluations': {8.91: 2.268434444039348,
#    6.703: 2.2264911926695343,
#    0.606: 0.24188029114933646},
#   'timestamp': '2025-02-02T23:02:51.690705Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(1 + tan(x)**2), x)',
#   'reasoning': 'As a geometry enthusiast, I consider the integral in terms of geometric transformations. I note the integral can be understood through the area under curves by translating it into the context of tangent and secant functions.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['simplify composite trigonometric functions',
#    'lower a coefficient',
#    'remove a factor'],
#   'solution': 'x*tan(x)**2/(2*tan(x)**2 + 2) + x/(2*tan(x)**2 + 2) + tan(x)/(2*tan(x)**2 + 2)',
#   'evaluations': {5.959: 2.8285348227006795,
#    -1.818: -0.7903620006404297,
#    -5.13: -2.3797038569630566},
#   'timestamp': '2025-02-02T23:02:51.780934Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/((2x - 1)^2 + 3/4), x)',
#   'reasoning': 'As a number theorist concentrated on rational coefficients, I can convert \\(x^2 - x + 1\\) into a more rational context by changing variable substitutions and finding rational approximations of solutions.',
#   'variant_response': None,
#   'verification_passed': False,
#   'evaluation': 'easier',
#   'transformations_used': ['simplify composite trigonometric functions',
#    'lower a coefficient',
#    'remove a factor'],
#   'solution': None,
#   'evaluations': {},
#   'timestamp': '2025-02-02T23:02:51.824651Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x**2 - 0.5x + 0.5), x)',
#   'reasoning': 'As an engineer, I realize reducing coefficients can directly make computations numerical easier, so it will be good to remove a factor in terms of scaling the entire function down.',
#   'variant_response': None,
#   'verification_passed': False,
#   'evaluation': 'equivalent',
#   'transformations_used': ['simplify composite trigonometric functions',
#    'lower a coefficient',
#    'remove a factor'],
#   'solution': None,
#   'evaluations': {},
#   'timestamp': '2025-02-02T23:02:51.746313Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(exp(x)), x)',
#   'reasoning': 'Theoretical physicists often work with exponential forms, so changing the integral to \\( \\frac{1}{e^x} \\) can make it more approachable since it leads to an easy result.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['change a function to an easier one',
#    'replace a complex fraction with a simpler one',
#    'convert a product to a simpler sum',
#    'remove nested functions',
#    'simplify the denominator'],
#   'solution': '-exp(-x)',
#   'evaluations': {-0.5: -1.6490768439731303,
#    -6.912: -1004.2060556933412,
#    -7.337: -1535.3568784554277},
#   'timestamp': '2025-02-02T23:02:51.811191Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/2, x)',
#   'reasoning': 'As a number theorist, I am drawn to integers. Integrating a constant with integer value simplifies calculations significantly, so I choose \\( 1/2 \\).',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['change a function to an easier one',
#    'replace a complex fraction with a simpler one',
#    'convert a product to a simpler sum',
#    'remove nested functions',
#    'simplify the denominator'],
#   'solution': 'x/2',
#   'evaluations': {2.716: 1.358225089103204,
#    -3.522: -1.7610267185471384,
#    -2.802: -1.401047730722408},
#   'timestamp': '2025-02-02T23:02:51.684367Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(x, x)',
#   'reasoning': 'A geometry enthusiast can visualize geometric transformations, transforming the integral into one with a geometric interpretation, such as integrating the area under \\( x \\) which is simply \\( x^2/2 \\).',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['change a function to an easier one',
#    'replace a complex fraction with a simpler one',
#    'convert a product to a simpler sum',
#    'remove nested functions',
#    'simplify the denominator'],
#   'solution': 'x**2/2',
#   'evaluations': {-7.512: 28.218409780313767,
#    8.906: 39.656567339371215,
#    -9.39: 44.08572951053764},
#   'timestamp': '2025-02-02T23:02:51.817373Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x**2), x)',
#   'reasoning': 'Simplifying the fraction \\( \\frac{1}{x^2} \\) makes it more manageable, and the result integrates to a simple form plus a constant.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['change a function to an easier one',
#    'replace a complex fraction with a simpler one',
#    'convert a product to a simpler sum',
#    'remove nested functions',
#    'simplify the denominator'],
#   'solution': '-1/x',
#   'evaluations': {0.725: -1.3795808843434,
#    -5.218: 0.19164331174876537,
#    -5.039: 0.1984664543734435},
#   'timestamp': '2025-02-02T23:02:51.718815Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/((x - 0.5)**2 + 0.75), x)',
#   'reasoning': 'As a calculus professor, I enjoy simplifying integrands. The expression can be reduced by completing the square in the denominator, making it easier to integrate.',
#   'variant_response': None,
#   'verification_passed': False,
#   'evaluation': 'easier',
#   'transformations_used': ['reduce the degree of a polynomial',
#    'reduce an exponent',
#    'convert a product to a simpler sum'],
#   'solution': None,
#   'evaluations': {},
#   'timestamp': '2025-02-02T23:02:51.682144Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x - 1/2)**2, x)',
#   'reasoning': "From a number theorist's angle, I notice that the roots of the denominator are not rational, so I can explore bounds of integration using rational values to constrain the problem.",
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['reduce the degree of a polynomial',
#    'reduce an exponent',
#    'convert a product to a simpler sum'],
#   'solution': '-4/(4*x - 2)',
#   'evaluations': {5.227: -0.2115400928551464,
#    -9.295: 0.10209451141852748,
#    -1.732: 0.4479449247163988},
#   'timestamp': '2025-02-02T23:02:51.839458Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x*(x - 1) + 1), x)',
#   'reasoning': 'I enjoy breaking down complex expressions; therefore, I will use a subtraction format to represent the integrand as simpler fractions.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['reduce the degree of a polynomial',
#    'reduce an exponent',
#    'convert a product to a simpler sum'],
#   'solution': '2*sqrt(3)*atan(2*sqrt(3)*x/3 - sqrt(3)/3)/3',
#   'evaluations': {0.809: 0.3955769633466529,
#    7.322: 1.668005141467096,
#    -7.625: -1.6911873369443509},
#   'timestamp': '2025-02-02T23:02:51.892261Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(1 + (x - 1/2)**2), x)',
#   'reasoning': 'As a student focused on polynomials, I want to simplify the expression by rewriting it in a rational function format, keeping in mind that certain manipulations can create simpler linear denominators.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['eliminate a radical',
#    'drop a subexpression',
#    'simplify a trigonometric component'],
#   'solution': 'atan(x - 1/2)',
#   'evaluations': {-2.885: -1.283545334560201,
#    5.917: 1.3882519387704633,
#    -2.475: -1.2465263114026874},
#   'timestamp': '2025-02-02T23:02:51.821851Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/y, x)',
#   'reasoning': 'As a pure mathematician, I propose making a substitution \\( y = x^2 - x + 1 \\), considering it as a fundamental polynomial structure, which might allow for a more straightforward inverse approach.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['eliminate a radical',
#    'drop a subexpression',
#    'simplify a trigonometric component'],
#   'solution': None,
#   'evaluations': {},
#   'timestamp': '2025-02-02T23:02:51.834968Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(3/4*(1 + (4/3)*(x - 1/2)**2)), x)',
#   'reasoning': 'From the standpoint of a theoretical physicist, I prefer to represent the integral in terms of a trigonometric substitution, which often simplifies the expression to a well-known form. Here, I use the relation to \\(\\tan\\) for integration.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['replace transcendental functions with simpler algebraic ones',
#    'reduce the number of terms in the expression',
#    'simplify the denominator'],
#   'solution': '2*sqrt(3)*atan(2*sqrt(3)*x/3 - sqrt(3)/3)/3',
#   'evaluations': {-8.866: -1.707337317916644,
#    4.433: 1.5635323941671904,
#    2.841: 1.404731771215213},
#   'timestamp': '2025-02-02T23:02:51.657088Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x**2 + 0.75), x)',
#   'reasoning': 'As an engineer, I value computational strategies. By substituting a constant term that simplifies the ratio, I can use numerical integration to solve for definite limits which would make it more practical for applied scenarios.',
#   'variant_response': None,
#   'verification_passed': False,
#   'evaluation': 'easier',
#   'transformations_used': ['replace transcendental functions with simpler algebraic ones',
#    'reduce the number of terms in the expression',
#    'simplify the denominator'],
#   'solution': None,
#   'evaluations': {},
#   'timestamp': '2025-02-02T23:02:51.949406Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x**2 + 3/4), x)',
#   'reasoning': 'From the perspective of a number theorist, I can focus on how the constant terms within the integrand can be removed to make it seem more analogous to forms involving roots. Approaching the polynomial structure can often declutter the integration process.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['replace transcendental functions with simpler algebraic ones',
#    'reduce the number of terms in the expression',
#    'simplify the denominator'],
#   'solution': '2*sqrt(3)*atan(2*sqrt(3)*x/3)/3',
#   'evaluations': {-6.413: -1.6588057573316706,
#    0.993: 0.9855572073031081,
#    1.387: 1.1693915463831395},
#   'timestamp': '2025-02-02T23:02:56.084655Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x**2 + x + 1), x)',
#   'reasoning': 'As a calculus professor looking for a simple substitution, I can transform the variable in a way that the result follows easily recognizable integration formulas or leads to simpler algebraic manipulation.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['replace transcendental functions with simpler algebraic ones',
#    'reduce the number of terms in the expression',
#    'simplify the denominator'],
#   'solution': '2*sqrt(3)*atan(2*sqrt(3)*x/3 + sqrt(3)/3)/3',
#   'evaluations': {0.768: 1.1217335085046138,
#    4.555: 1.6178917373931188,
#    0.933: 1.186031230231571},
#   'timestamp': '2025-02-02T23:02:51.813867Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x * (x - 1) + 1), x)',
#   'reasoning': 'From the view of a student focused on rational functions, treating the denominator as a quadratic that I can factor into simpler components allows for an easy piecing together of partial fractions.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['replace transcendental functions with simpler algebraic ones',
#    'reduce the number of terms in the expression',
#    'simplify the denominator'],
#   'solution': '2*sqrt(3)*atan(2*sqrt(3)*x/3 - sqrt(3)/3)/3',
#   'evaluations': {2.039: 1.2220088121271317,
#    -0.902: -1.1748703183564952,
#    8.543: 1.689951563457973},
#   'timestamp': '2025-02-02T23:02:51.749007Z'},
#  {'original': 'integrate(1/(x**2 - x + 1), x)',
#   'requested_difficulty': 'easier',
#   'variant': 'integrate(1/(x**2 + 1/4), x)',
#   'reasoning': 'As a geometry enthusiast, I relate integration to areas under curves. I propose a geometric interpretation of a rectangular approximation or the area under a simpler quadratic polynomial, making the integration much simpler.',
#   'variant_response': None,
#   'verification_passed': True,
#   'evaluation': 'easier',
#   'transformations_used': ['eliminate absolute value terms',
#    'replace transcendental functions with simpler algebraic ones',
#    'convert a product to a simpler sum',
#    'remove a complicated term',
#    'remove nested functions'],
#   'solution': '2*atan(2*x)',
#   'evaluations': {-9.543: -3.036896230944346,
#    -1.824: -2.606399941837475,
#    8.83: 3.028462149194476},
#   'timestamp': '2025-02-02T23:02:51.830336Z'}]

# %%
from generate_variants_general import process_expression
base_expr = "∫𝜋/20cos𝑥2−sin2𝑥𝑑𝑥"  # Example expression
difficulties = ["easier", "equivalent", "harder"]
print("Processing expression:", base_expr)
variants = await process_expression(base_expr, difficulties, num_variants=3)
# Out:
# Processing expression: sin(x)**2 + cos(x)**2
# Error verifying expression: Sympify of expression 'could not parse 'sqrt(1 - x**2)**2 + x**2 (where x = cos(theta) or sin(theta))'' failed, because of exception being raised:
# SyntaxError: invalid syntax (<string>, line 1)

# %%
variants
# Out:
# [{'original': 'sin(x)**2 + cos(x)**2',
#   'requested_difficulty': 'easier',
#   'variant': '1',
#   'reasoning': 'As a calculus professor who loves elegant simplifications, I recognize the fundamental Pythagorean identity from trigonometry, which states that sin(x)**2 + cos(x)**2 = 1. This simplifies the expression to the constant 1.',
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['remove nested functions',
#    'lower a coefficient',
#    'eliminate absolute value terms',
#    'convert a product to a simpler sum',
#    'reduce the number of terms in the expression'],
#   'evaluations': {-3.12: 1.0, -8.899: 1.0, -4.342: 1.0},
#   'timestamp': '2025-02-04T07:12:58.388534Z'},
#  {'original': 'sin(x)**2 + cos(x)**2',
#   'requested_difficulty': 'easier',
#   'variant': 'sec(x)**2 - tan(x)**2',
#   'reasoning': 'As a creative mathematician who enjoys unusual substitutions, I consider expressing the trigonometric identity in terms of tangent by dividing both sides by cos(x)**2, leading to tan(x)**2 + 1 = sec(x)**2. This changes the form without altering the identity.',
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['remove nested functions',
#    'lower a coefficient',
#    'eliminate absolute value terms',
#    'convert a product to a simpler sum',
#    'reduce the number of terms in the expression'],
#   'evaluations': {-8.352: 1.0, -0.404: 1.0, 9.423: 1.0},
#   'timestamp': '2025-02-04T07:12:58.781173Z'},
#  {'original': 'sin(x)**2 + cos(x)**2',
#   'requested_difficulty': 'easier',
#   'variant': '1/(1 + tan(x)**2)',
#   'reasoning': 'As a student who prefers working with polynomials and rational functions, I can rewrite the identity involving polynomial-like terms in the numerator and denominator by utilizing secant and tangent relations.',
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['remove nested functions',
#    'lower a coefficient',
#    'eliminate absolute value terms',
#    'convert a product to a simpler sum',
#    'reduce the number of terms in the expression'],
#   'evaluations': {2.093: 0.24867202909721345,
#    1.634: 0.0039490731651922,
#    -7.542: 0.09405410562446878},
#   'timestamp': '2025-02-04T07:12:58.552064Z'},
#  {'original': 'sin(x)**2 + cos(x)**2',
#   'requested_difficulty': 'equivalent',
#   'variant': '1 - cos(x)**2 + cos(x)**2',
#   'reasoning': "As a creative mathematician, I employ an unusual substitution: let's consider \\(\\sin(x)^2 = 1 - \\cos(x)^2\\). This keeps the equivalence intact.",
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['alter constant terms',
#    'swap numerator and denominator with reciprocal',
#    'adjust parameters while keeping the integral equivalent'],
#   'evaluations': {-4.101: 1.0, -8.894: 1.0, -5.967: 1.0},
#   'timestamp': '2025-02-04T07:13:03.702204Z'},
#  {'original': 'sin(x)**2 + cos(x)**2',
#   'requested_difficulty': 'equivalent',
#   'variant': '(sin(x) - cos(x))**2 + 2*sin(x)*cos(x)',
#   'reasoning': "As a student who enjoys polynomials, I'll use the fact that squaring a binomial and breaking it down maintains equality: \\((\\sin(x) - \\cos(x))^2 + 2\\sin(x)\\cos(x)\\).",
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['alter constant terms',
#    'swap numerator and denominator with reciprocal',
#    'adjust parameters while keeping the integral equivalent'],
#   'evaluations': {8.968: 1.0, 0.914: 1.0, 0.085: 1.0},
#   'timestamp': '2025-02-04T07:13:03.328812Z'},
#  {'original': 'sin(x)**2 + cos(x)**2',
#   'requested_difficulty': 'equivalent',
#   'variant': '(exp(I*x)).expand(complex=True).as_real_imag()[0]**2 + (exp(I*x)).expand(complex=True).as_real_imag()[1]**2',
#   'reasoning': "As a theoretical physicist, I appreciate exponential identities. Utilizing Euler's formula, I will write \\(\\sin(x) = \\frac{e^{ix} - e^{-ix}}{2i}\\) and \\(\\cos(x) = \\frac{e^{ix} + e^{-ix}}{2}\\), leading to \\(|e^{ix}|^2 = 1\\).",
#   'verification_passed': True,
#   'evaluation': 'equivalent',
#   'transformations_used': ['alter constant terms',
#    'swap numerator and denominator with reciprocal',
#    'adjust parameters while keeping the integral equivalent'],
#   'evaluations': {6.877: 1.0, 1.948: 1.0, -7.75: 1.0},
#   'timestamp': '2025-02-04T07:13:03.562111Z'},
#  {'original': 'sin(x)**2 + cos(x)**2',
#   'requested_difficulty': 'harder',
#   'variant': 'sin(x)**2 + cos(x)**2 + 2*sin(x)*cos(x)',
#   'reasoning': 'As a calculus professor who loves elegant simplifications, I can increase the complexity by adding an extra trigonometric term that does not maintain orthogonality. A term like 2*sin(x)*cos(x) adds a twist.',
#   'verification_passed': True,
#   'evaluation': 'harder',
#   'transformations_used': ['add a non-linear term',
#    'insert a logarithmic factor',
#    'introduce an additional polynomial factor',
#    'increase the exponent',
#    'add a product of functions'],
#   'evaluations': {-8.472: 1.944776552844538,
#    0.376: 1.6835357780650468,
#    -9.138: 1.5418714423652864},
#   'timestamp': '2025-02-04T07:12:58.857239Z'},
#  {'original': 'sin(x)**2 + cos(x)**2',
#   'requested_difficulty': 'harder',
#   'variant': 'sin(x)**2 + cos(x)**2 + log(1 + sin(x))',
#   'reasoning': "As a creative mathematician, I enjoy using unusual substitutions. Introducing a logarithmic factor and a sine term creates an interesting variation that isn't easily simplified.",
#   'verification_passed': True,
#   'evaluation': 'harder',
#   'transformations_used': ['add a non-linear term',
#    'insert a logarithmic factor',
#    'introduce an additional polynomial factor',
#    'increase the exponent',
#    'add a product of functions'],
#   'evaluations': {1.659: 1.691205069845424,
#    -7.689: -3.303150868938993,
#    -5.702: 1.4375495041725812},
#   'timestamp': '2025-02-04T07:12:58.682061Z'},
#  {'original': 'sin(x)**2 + cos(x)**2',
#   'requested_difficulty': 'harder',
#   'variant': '(sin(x)**2 + cos(x)**2) * (x**2 + 1)',
#   'reasoning': 'A student who works with polynomials and rational functions might transform the expression by including a polynomial multiplied by the original form to observe the behavior of the expanded terms.',
#   'verification_passed': True,
#   'evaluation': 'harder',
#   'transformations_used': ['add a non-linear term',
#    'insert a logarithmic factor',
#    'introduce an additional polynomial factor',
#    'increase the exponent',
#    'add a product of functions'],
#   'evaluations': {-7.96: 64.36679004335959,
#    0.651: 1.424255069042168,
#    -6.178: 39.165935902285256},
#   'timestamp': '2025-02-04T07:12:58.814889Z'}]
